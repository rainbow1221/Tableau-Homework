# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Import 2018 csv files
m12_2018 = pd.read_csv("../data_sets/JC-201812-citibike-tripdata.csv")
m11_2018 = pd.read_csv("../data_sets/JC-201811-citibike-tripdata.csv")
m10_2018 = pd.read_csv("../data_sets/JC-201810-citibike-tripdata.csv")
m9_2018 = pd.read_csv("../data_sets/JC-201809-citibike-tripdata.csv")
m8_2018 = pd.read_csv("../data_sets/JC-201808-citibike-tripdata.csv")
m7_2018 = pd.read_csv("../data_sets/JC-201807-citibike-tripdata.csv")
m6_2018 = pd.read_csv("../data_sets/JC-201806-citibike-tripdata.csv")
m5_2018 = pd.read_csv("../data_sets/JC-201805-citibike-tripdata.csv")
m4_2018 = pd.read_csv("../data_sets/JC-201804-citibike-tripdata.csv")
m3_2018 = pd.read_csv("../data_sets/JC-201803-citibike-tripdata.csv")
m2_2018 = pd.read_csv("../data_sets/JC-201802-citibike-tripdata.csv")
m1_2018 = pd.read_csv("../data_sets/JC-201801-citibike-tripdata.csv")

# %%
m12_2018_df=m12_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m11_2018_df=m11_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m10_2018_df=m10_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m9_2018_df=m9_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m8_2018_df=m8_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m7_2018_df=m7_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m6_2018_df=m6_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m5_2018_df=m5_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m4_2018_df=m4_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m3_2018_df=m3_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m2_2018_df=m2_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m1_2018_df=m1_2018.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()

# %%
m1_2018_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
#combind 2018 data to one table in database
#m1_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m2_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m3_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m4_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m5_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m6_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m7_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m8_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m9_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m10_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m11_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)
#m12_2018_df.to_sql(name='tripdata_2018', con=engine, if_exists='append', index=False)

# %%
database_path = "etl"
engine = create_engine(f"sqlite:///{database_path}")

# %%
#export data from table in database to pandas dataFrame
tripdata_2018_df=pd.read_sql_query('select * from tripdata_2018 order by starttime', con=engine)

# %%
tripdata_2018_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           132  2018-01-01 00:01:45.8140  2018-01-01 00:03:58.4750
# 1           560  2018-01-01 01:27:17.2720  2018-01-01 01:36:37.8410
# 2           294  2018-01-01 01:29:03.0200  2018-01-01 01:33:57.8990
# 3           197  2018-01-01 01:59:31.7460  2018-01-01 02:02:48.9960
# 4           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3276   Marin Light Rail               40.714584
# 2              3195            Sip Ave               40.730743
# 3              3211         Newark Ave               40.721525
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id       end station name  \
# 0               -74.043117            3211             Newark Ave
# ...

# %%
#m12_2018_df.to_sql(name='tripdata_m12_2018', con=engine, if_exists='append', index=False)

# %%
tripdata_m12_2018_df=pd.read_sql_query('select * from tripdata_m12_2018 order by starttime', con=engine)

# %%
# export data from padas to csv file
tripdata_2018_df.to_csv("../data_sets/tripdata_2018.csv",index=False, header=True)

# %%
# export data from padas to csv file
tripdata_m12_2018_df.to_csv("../data_sets/tripdata_m12_2018.csv",index=False, header=True)

# %%
# Import 2017 csv files
m12_2017 = pd.read_csv("../data_sets/JC-201712-citibike-tripdata.csv")
m11_2017 = pd.read_csv("../data_sets/JC-201711-citibike-tripdata.csv")
m10_2017 = pd.read_csv("../data_sets/JC-201710-citibike-tripdata.csv")
m9_2017 = pd.read_csv("../data_sets/JC-201709-citibike-tripdata.csv")
m8_2017 = pd.read_csv("../data_sets/JC-201708-citibike-tripdata.csv")
m7_2017 = pd.read_csv("../data_sets/JC-201707-citibike-tripdata.csv")
m6_2017 = pd.read_csv("../data_sets/JC-201706-citibike-tripdata.csv")
m5_2017 = pd.read_csv("../data_sets/JC-201705-citibike-tripdata.csv")
m4_2017 = pd.read_csv("../data_sets/JC-201704-citibike-tripdata.csv")
m3_2017 = pd.read_csv("../data_sets/JC-201703-citibike-tripdata.csv")
m2_2017 = pd.read_csv("../data_sets/JC-201702-citibike-tripdata.csv")
m1_2017 = pd.read_csv("../data_sets/JC-201701-citibike-tripdata.csv")

# %%
m3_2017.head()
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0          1076  3/1/17 0:03  3/1/17 0:20              3275
# 1           978  3/1/17 0:09  3/1/17 0:25              3220
# 2          1789  3/1/17 0:28  3/1/17 0:58              3195
# 3           613  3/1/17 0:52  3/1/17 1:02              3194
# 4          2418  3/1/17 0:54  3/1/17 1:34              3199
#
#   start station name  start station latitude  start station longitude  \
# 0     Columbus Drive               40.718355               -74.038914
# 1  5 Corners Library               40.734961               -74.059503
# 2            Sip Ave               40.730743               -74.063784
# 3    McGinley Square               40.725340               -74.067622
# 4       Newport Pkwy               40.728745               -74.032108
#
#    end station id      end station name  end station latitude  \
# 0            3207           Oakland Ave             40.737604
# ...

# %%
m4_2017.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           252  2017-04-01 00:14:36  2017-04-01 00:18:48              3186
# 1           452  2017-04-01 00:15:47  2017-04-01 00:23:20              3203
# 2           465  2017-04-01 00:46:27  2017-04-01 00:54:13              3271
# 3           417  2017-04-01 00:47:15  2017-04-01 00:54:13              3271
# 4           391  2017-04-01 01:13:12  2017-04-01 01:19:44              3183
#
#     start station name  start station latitude  start station longitude  \
# 0        Grove St PATH               40.719586               -74.043117
# 1        Hamilton Park               40.727596               -74.044247
# 2  Danforth Light Rail               40.692640               -74.088012
# 3  Danforth Light Rail               40.692640               -74.088012
# 4       Exchange Place               40.716247               -74.033459
#
#    end station id end station name  end station latitude  \
# ...

# %%
#format the column
m12_2017_df=m11_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m11_2017_df=m11_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m10_2017_df=m10_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m9_2017_df=m9_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m8_2017_df=m8_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m7_2017_df=m7_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m6_2017_df=m6_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m5_2017_df=m5_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m4_2017_df=m4_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m3_2017_df=m3_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m2_2017_df=m2_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()
m1_2017_df=m1_2017.reindex(columns=['tripduration','starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude','bikeid','usertype','birth year','gender']).copy()

# %%
m1_2017_df.head()
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0           148  1/1/17 0:21  1/1/17 0:24              3276
# 1          1283  1/1/17 0:24  1/1/17 0:45              3183
# 2           372  1/1/17 0:38  1/1/17 0:44              3183
# 3          1513  1/1/17 0:38  1/1/17 1:03              3194
# 4           639  1/1/17 1:47  1/1/17 1:58              3183
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id     end station name  end station latitude  \
# 0            3185            City Hall             40.717733
# ...

# %%
database_path = "etl"
engine = create_engine(f"sqlite:///{database_path}")

# %%
#combind 2017 data to one table in database
#m1_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m2_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m3_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m4_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m5_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m6_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m7_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m8_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m9_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m10_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m11_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)
#m12_2017_df.to_sql(name='tripdata_2017_tb3', con=engine, if_exists='append', index=False)

# %%
#export data from table in database to pandas dataFrame
tripdata_2017_df=pd.read_sql_query('select * from tripdata_2017_tb3 order by starttime', con=engine)

# %%
tripdata_2017_df.head()
# Out:
#    tripduration     starttime      stoptime  start station id  \
# 0           148   1/1/17 0:21   1/1/17 0:24              3276
# 1          1283   1/1/17 0:24   1/1/17 0:45              3183
# 2           372   1/1/17 0:38   1/1/17 0:44              3183
# 3          1513   1/1/17 0:38   1/1/17 1:03              3194
# 4           424  1/1/17 10:03  1/1/17 10:10              3267
#
#   start station name  start station latitude  start station longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4       Morris Canal               40.712419               -74.038526
#
#    end station id     end station name  end station latitude  \
# 0            3185            City Hall             40.717733
# ...

# %%
# export data from padas to csv file
tripdata_2017_df.to_csv("../data_sets/tripdata_2017.csv",index=False, header=True)

# %%
#m12_2017_df.to_sql(name='tripdata_M12_2017', con=engine, if_exists='append', index=False)

# %%
tripdata_m12_2017_df=pd.read_sql_query('select * from tripdata_M12_2017 order by starttime', con=engine)

# %%
tripdata_m12_2017_df.to_csv("../data_sets/tripdata_m12_2017.csv",index=False, header=True)
